# %%
import requests
from requests.exceptions import ConnectionError
import lxml.html as lh
import pandas as pd
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
companies1 = pd.read_csv('List_of_companies.csv', encoding = "ISO-8859-1") #unmodified names
companies = pd.read_csv('List_of_companies_Full.csv', encoding = "ISO-8859-1") #will have modified names

print(companies.dtypes)

companies['Security'] = companies['Security'].str.replace(u'\xa0', u' ')#this was messing with the classes
companies['Security'] = companies['Security'].str.replace(r' \(Class A\)', '')#some companies are liste multiple times because of class of stock
companies['Security'] = companies['Security'].str.replace(r' \(Class B\)', '')#some companies are liste multiple times because of class of stock
companies['Security'] = companies['Security'].str.replace(r' \(Class C\)', '')#some companies are liste multiple times because of class of stock
companies['Security'] = companies['Security'].str.replace(r'\(', '')#need to remove parenthesis too for the url
companies['Security'] = companies['Security'].str.replace(r'\)', '')
companies['Security'] = companies['Security'].str.replace(r'\.com', '-com')#for amazon and salesforce
companies['Security'] = companies['Security'].str.replace(r'Corporation', 'corp')#corporation got shortened to corp
companies['Security'] = companies['Security'].str.replace(r'corporation', 'corp')
companies['Security'] = companies['Security'].str.replace(r'Company', 'co')#company got shortened to co
companies['Security'] = companies['Security'].str.replace(r'company', 'co')
companies['Security'] = companies['Security'].str.replace(r'&', 'and')#& is and for some reason
companies['Security'] = companies['Security'].str.replace(r' ', '-')#the url uses hyphens a lot
companies['Security'] = companies['Security'].str.replace(r'.', '')#don't want these here
companies['Security'] = companies['Security'].str.replace(r',', '')
companies['Security'] = companies['Security'].str.replace(r'!', '')
companies['Security'] = companies['Security'].str.replace(r'\'', '')

companies['Security'] = companies['Security'].str.lower()#lowercases everything
print(len(companies))
companies
# Out:
# Symbol                   object
# Security                 object
# SEC filings              object
# GICS Sector              object
# GICS Sub-Industry        object
# Headquarters Location    object
# Date first added         object
# CIK                       int64
# Founded                  object
# dtype: object
# 500
#     Symbol                         Security SEC filings  \
# 0      MMM                            3m-co     reports
# 1      ABT              abbott-laboratories     reports
# 2     ABBV                       abbvie-inc     reports
# 3     ABMD                      abiomed-inc     reports
# 4      ACN                    accenture-plc     reports
# 5     ATVI              activision-blizzard     reports
# 6     ADBE                        adobe-inc     reports
# 7      AMD       advanced-micro-devices-inc     reports
# 8      AAP               advance-auto-parts     reports
# 9      AES                     aes-corp-the     reports
# 10     AFL                        aflac-inc     reports
# 11       A         agilent-technologies-inc     reports
# 12     APD   air-products-and-chemicals-inc     reports
# 13    AKAM          akamai-technologies-inc     reports
# 14     ALK             alaska-air-group-inc     reports
# 15     ALB                   albemarle-corp     reports
# 16     ARE  alexandria-real-estate-equities     reports
# 17    ALXN          alexion-pharmaceuticals     reports
# 18    ALGN                 align-technology     reports
# 19    ALLE                         allegion     reports
# 20     LNT              alliant-energy-corp     reports
# 21     ALL                    allstate-corp     reports
# 22    GOOG                     alphabet-inc     reports
# 23      MO                 altria-group-inc     reports
# 24    AMZN                   amazon-com-inc     reports
# 25    AMCR                        amcor-plc     reports
# 26     AEE                      ameren-corp     reports
# 27     AAL          american-airlines-group     reports
# 28     AEP          american-electric-power     reports
# 29     AXP              american-express-co     reports
# ..     ...                              ...         ...
# 470    VNO             vornado-realty-trust     reports
# 471    VMC                 vulcan-materials     reports
# 472    WRB                 berkley-w-r-corp     reports
# 473    WAB                      wabtec-corp     reports
# 474    WMT                          walmart     reports
# 475    WBA         walgreens-boots-alliance     reports
# 476    DIS                   disney-walt-co     reports
# 477     WM             waste-management-inc     reports
# 478    WAT                      waters-corp     reports
# 479    WEC                 wec-energy-group     reports
# 480    WFC       wells-fargo-and-company-mn     reports
# 481   WELL                    welltower-inc     reports
# 482    WST     west-pharmaceutical-svsc-inc     reports
# 483    WDC                  western-digital     reports
# 484     WU                 western-union-co     reports
# 485    WRK                         westrock     reports
# 486     WY                     weyerhaeuser     reports
# 487    WHR                   whirlpool-corp     reports
# 488    WMB                 williams-cos-inc     reports
# 489   WLTW             willis-towers-watson     reports
# 490   WYNN                 wynn-resorts-ltd     reports
# 491    XEL                  xcel-energy-inc     reports
# 492    XRX                            xerox     reports
# 493   XLNX                           xilinx     reports
# 494    XYL                        xylem-inc     reports
# 495    YUM                   yum-brands-inc     reports
# 496   ZBRA       zebra-technologies-cp-cl-a     reports
# 497    ZBH       zimmer-biomet-holdings-inc     reports
# 498   ZION          zions-bancorporation-na     reports
# 499    ZTS                           zoetis     reports
#
#                 GICS Sector                             GICS Sub-Industry  \
# 0               Industrials                      Industrial Conglomerates
# 1               Health Care                         Health Care Equipment
# 2               Health Care                               Pharmaceuticals
# 3               Health Care                         Health Care Equipment
# 4    Information Technology                IT Consulting & Other Services
# 5    Communication Services                Interactive Home Entertainment
# 6    Information Technology                          Application Software
# 7    Information Technology                                Semiconductors
# 8    Consumer Discretionary                             Automotive Retail
# 9                 Utilities  Independent Power Producers & Energy Traders
# 10               Financials                       Life & Health Insurance
# 11              Health Care                         Health Care Equipment
# 12                Materials                              Industrial Gases
# 13   Information Technology            Internet Services & Infrastructure
# 14              Industrials                                      Airlines
# 15                Materials                           Specialty Chemicals
# 16              Real Estate                                  Office REITs
# 17              Health Care                                 Biotechnology
# 18              Health Care                          Health Care Supplies
# 19              Industrials                             Building Products
# 20                Utilities                            Electric Utilities
# 21               Financials                 Property & Casualty Insurance
# 22   Communication Services                  Interactive Media & Services
# 23         Consumer Staples                                       Tobacco
# 24   Consumer Discretionary            Internet & Direct Marketing Retail
# 25                Materials                               Paper Packaging
# 26                Utilities                               Multi-Utilities
# 27              Industrials                                      Airlines
# 28                Utilities                            Electric Utilities
# 29               Financials                              Consumer Finance
# ..                      ...                                           ...
# 470             Real Estate                                  Office REITs
# 471               Materials                        Construction Materials
# 472              Financials                 Property & Casualty Insurance
# 473             Industrials         Construction Machinery & Heavy Trucks
# 474        Consumer Staples                  Hypermarkets & Super Centers
# 475        Consumer Staples                                   Drug Retail
# 476  Communication Services                        Movies & Entertainment
# 477             Industrials           Environmental & Facilities Services
# 478             Health Care                      Health Care Distributors
# 479               Utilities                            Electric Utilities
# 480              Financials                             Diversified Banks
# 481             Real Estate                             Health Care REITs
# 482             Health Care                          Health Care Supplies
# 483  Information Technology    Technology Hardware, Storage & Peripherals
# 484  Information Technology         Data Processing & Outsourced Services
# 485               Materials                               Paper Packaging
# 486             Real Estate                             Specialized REITs
# 487  Consumer Discretionary                          Household Appliances
# 488                  Energy            Oil & Gas Storage & Transportation
# 489              Financials                             Insurance Brokers
# 490  Consumer Discretionary                              Casinos & Gaming
# 491               Utilities                               Multi-Utilities
# 492  Information Technology    Technology Hardware, Storage & Peripherals
# 493  Information Technology                                Semiconductors
# 494             Industrials                          Industrial Machinery
# 495  Consumer Discretionary                                   Restaurants
# 496  Information Technology            Electronic Equipment & Instruments
# 497             Health Care                         Health Care Equipment
# 498              Financials                                Regional Banks
# 499             Health Care                               Pharmaceuticals
#
#                 Headquarters Location Date first added      CIK      Founded
# 0                 St. Paul, Minnesota         8/9/1976    66740         1902
# 1             North Chicago, Illinois        3/31/1964     1800         1888
# 2             North Chicago, Illinois       12/31/2012  1551152  2013 (1888)
# 3              Danvers, Massachusetts        5/31/2018   815094         1981
# 4                     Dublin, Ireland         7/6/2011  1467373         1989
# 5            Santa Monica, California        8/31/2015   718877         2008
# 6                San Jose, California         5/5/1997   796343         1982
# 7             Santa Clara, California        3/20/2017     2488         1969
# 8             Raleigh, North Carolina         7/9/2015  1158449         1932
# 9                 Arlington, Virginia        10/2/1998   874761         1981
# 10                  Columbus, Georgia        5/28/1999     4977         1955
# 11            Santa Clara, California         6/5/2000  1090872         1999
# 12            Allentown, Pennsylvania        4/30/1985     2969         1940
# 13           Cambridge, Massachusetts        7/12/2007  1086222         1998
# 14                Seattle, Washington        5/13/2016   766421         1985
# 15          Charlotte, North Carolina         7/1/2016   915913         1994
# 16               Pasadena, California        3/20/2017  1035443         1994
# 17              Boston, Massachusetts        5/25/2012   899866         1992
# 18               San Jose, California        6/19/2017  1097149         1997
# 19                    Dublin, Ireland        12/2/2013  1579241         1908
# 20                 Madison, Wisconsin         7/1/2016   352541         1917
# 21      Northfield Township, Illinois        7/13/1995   899051         1931
# 22          Mountain View, California         4/3/2006  1652044         1998
# 23                 Richmond, Virginia         3/4/1957   764180         1985
# 24                Seattle, Washington       11/18/2005  1018724         1994
# 25   Warmley, Bristol, United Kingdom         6/7/2019  1748790  2019 (1860)
# 26                St. Louis, Missouri        9/19/1991  1002910         1902
# 27                  Fort Worth, Texas        3/23/2015     6201         1934
# 28                     Columbus, Ohio         3/4/1957     4904         1906
# 29                 New York, New York        6/30/1976     4962         1850
# ..                                ...              ...      ...          ...
# 470                New York, New York              NaN   899689         1982
# 471               Birmingham, Alabama        6/30/1999  1396009         1909
# 472            Greenwich, Connecticut        12/5/2019    11544         1967
# 473          Wilmerding, Pennsylvania        2/27/2019   943452  1999 (1869)
# 474             Bentonville, Arkansas        8/31/1982   104169         1962
# 475               Deerfield, Illinois       12/31/1979  1618921         2014
# 476               Burbank, California        6/30/1976  1744489         1923
# 477                    Houston, Texas              NaN   823768         1968
# 478            Milford, Massachusetts              NaN  1000697         1958
# 479              Milwaukee, Wisconsin       10/31/2008   783325         1896
# 480         San Francisco, California        6/30/1976    72971         1852
# 481                      Toledo, Ohio        1/30/2009   766704         1970
# 482               Exton, Pennsylvania        5/22/2020   105770         1923
# 483              San Jose, California         7/1/2009   106040         1970
# 484               Englewood, Colorado        9/29/2006  1365135         1851
# 485                  Atlanta, Georgia              NaN  1732845         2015
# 486           Federal Way, Washington              NaN   106535         1900
# 487           Benton Harbor, Michigan              NaN   106640         1911
# 488                   Tulsa, Oklahoma        3/31/1975   107263         1908
# 489            London, United Kingdom         1/5/2016  1140536         2016
# 490                  Paradise, Nevada       11/14/2008  1174922         2002
# 491            Minneapolis, Minnesota         3/4/1957    72903         1909
# 492              Norwalk, Connecticut              NaN  1770450         1906
# 493              San Jose, California        11/8/1999   743988         1984
# 494            White Plains, New York        11/1/2011  1524472         2011
# 495              Louisville, Kentucky        10/6/1997  1041061         1997
# 496            Lincolnshire, Illinois       12/23/2019   877212         1969
# 497                   Warsaw, Indiana         8/7/2001  1136869         1927
# 498              Salt Lake City, Utah        6/22/2001   109380         1873
# 499          Florham Park, New Jersey        6/21/2013  1555280         1952
#
# [500 rows x 9 columns]

# %%
#utilities
def getUrl(n, mod = ''):
    currName = companies.at[n, 'Security']
    url='https://www1.salary.com/' + currName + mod + '-Executive-Salaries.html'
    page=requests.get(url)
    return page

def getIncUrl(n):
    currName = companies.at[n, 'Security']
    url='https://www1.salary.com/' + currName + '-inc' + '-Executive-Salaries.html'
    page=requests.get(url)
    return page

def getCoUrl(n):
    currName = companies.at[n, 'Security']
    url='https://www1.salary.com/' + currName + '-co' + '-Executive-Salaries.html'
    page=requests.get(url)
    return page

def getCorpUrl(n):
    currName = companies.at[n, 'Security']
    url='https://www1.salary.com/' + currName + '-corp' + '-Executive-Salaries.html'
    page=requests.get(url)
    return page

def getPlcUrl(n):
    currName = companies.at[n, 'Security']
    url='https://www1.salary.com/' + currName + '-plc' + '-Executive-Salaries.html'
    page=requests.get(url)
    return page

def getContent(page):
    doc=lh.fromstring(page.content)
    tr_elements=doc.xpath('//tr')
    return tr_elements

# %%
def failureCase(col, good, alt_tr_elements):
    for j in range(0,len(alt_tr_elements)):
        #T is our j'th row
        T=alt_tr_elements[j]

        #Only check rows of size 4 (with CEO Name, CEO Pay, Median Employee Pay,
        #and CEO Pay Ratio)
        if len(T)==4:
            #checks if the current row has the 4 maagic words
            table_Name = ['','','','']
            i=0
            for t in T:
                name = t.text_content()
                name = name.__str__()
                table_Name[i]=name
                i+=1

            #if it does, I'll take the data from the row right below it
            if (table_Name[0] == 'CEO Name' and table_Name[1] == 'CEO Pay' and table_Name[2] == 'Median Employee Pay' and table_Name[3] == 'CEO Pay Ratio'):
                T=alt_tr_elements[j+1]
                #i is the index of our column
                i=0

                #this is a temporary storage of the content of each line of the csv
                content = []

                #Iterate through each element of the row
                for t in T.iterchildren():
                    #this part if for cleaning the cell contents
                    data=t.text_content() #gets the content of cell
                    data = data.__str__() #turns content to string
                    data = data.replace(r'$', '') #takes out dollar sign for number conversion
                    data = data.replace(r',', '') #takes out comma for number conversion
                    data = data.strip() #clears our \r and \n and spaces, cleans up the content string
                    data = data.replace(r'CEO Pay', '') #cleans up the content string
                    data = data.replace(r'Median Employee Pay', '') #cleans up the content string
                    data = data.replace(r'CEO Pay Ratio', '') #cleans up the content string
                    data = data.replace(r'Ratio', '') #cleans up the content string
                    data = data.replace(r':1', '') #takes out :1 in the ratio for number conversion
                    data = data.strip() #clears our \r and \n and spaces again to finish cleaning up

                    content.append(data)

                    #Check if row is empty
                    if i>0:
                    #Convert any numerical value to integers
                        try:
                            data=int(data)
                        except:
                            pass
                    #Append the data to col
                    col[i + 1][1].append(data)
                    #Increment i for the next column
                    i+=1
                #col[0][1].append(currName1)
                return True

        return False

# %%
#Makes a list of to make the graph later on
col=[('Security', [])]

# %%
#goes through all the webpages
for n in range(len(companies)):
    currName = companies.at[n, 'Security']
    add = currName
    #getting url
    url='https://www1.salary.com/' + currName + '-Executive-Salaries.html'
    page=requests.get(url)
    #getting all the tables
    tr_elements=getContent(page)
    #indicates that we failed to find the magics on this particular page
    fail = True
    for j in range(0,len(tr_elements)):
        #T is our j'th row
        T=tr_elements[j]

        #Only check rows of size 4 (with CEO Name, CEO Pay, Median Employee Pay,
        #and CEO Pay Ratio)
        if len(T)==4:
            #checks if the current row has the 4 maagic words
            table_Name = ['','','','']
            i=0
            for t in T:
                name = t.text_content()
                name = name.__str__()
                table_Name[i]=name
                i+=1

            #if it does, I'll take the data from the row right below it
            if (table_Name[0] == 'CEO Name' and table_Name[1] == 'CEO Pay' and table_Name[2] == 'Median Employee Pay' and table_Name[3] == 'CEO Pay Ratio'):
                #print(currName1 + ' good')
                #setting fail to false
                fail = False
                add = currName
                break
    
    if fail:
        #print(currName1)
        #print(currName)
        #print(url)
        #put these into the get url
        alts = ['-inc','-co','-corp','-plc','-new']
        #good indicated whether or not the new url works
        good = False
        for i in range(len(alts)):
            currName = currName + alts[i]
            url='https://www1.salary.com/' + currName + '-Executive-Salaries.html'
            page=requests.get(url)
            alt_tr_elements=getContent(page)
            for j in range(0,len(alt_tr_elements)):
                #T is our j'th row
                T=alt_tr_elements[j]

                #Only check rows of size 4 (with CEO Name, CEO Pay, Median Employee Pay,
                #and CEO Pay Ratio)
                if len(T)==4:
                    #checks if the current row has the 4 maagic words
                    table_Name = ['','','','']
                    i=0
                    for t in T:
                        name = t.text_content()
                        name = name.__str__()
                        table_Name[i]=name
                        i+=1

                    #if it does, I'll take the data from the row right below it
                    if (table_Name[0] == 'CEO Name' and table_Name[1] == 'CEO Pay' and table_Name[2] == 'Median Employee Pay' and table_Name[3] == 'CEO Pay Ratio'):
                        #print(currName1 + ' good')
                        T=alt_tr_elements[j+1]
                        good = True
            if good:
                add = currName
                break
    col[0][1].append(add)
    print(n, add)
# Out:
# 0 3m-co
# 1 abbott-laboratories
# 2 abbvie-inc
# 3 abiomed-inc
# 4 accenture-plc
# 5 activision-blizzard-inc
# 6 adobe-inc
# 7 advanced-micro-devices-inc
# 8 advance-auto-parts-inc
# 9 aes-corp-the
# 10 aflac-inc
# 11 agilent-technologies-inc
# 12 air-products-and-chemicals-inc
# 13 akamai-technologies-inc
# 14 alaska-air-group-inc
# 15 albemarle-corp
# 16 alexandria-real-estate-equities

# %%
col

# %%
len(col[0][1])

# %%
#making the dataframe
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %%
#displaying the dataframe
df

# %%
"""int = 0
for i in range(len(df)):
    if (df.at[i, 'Median Employee Pay'] > -1):
        int += 1
print(int)
print(len(df)-int)"""

# %% [markdown]
# int = 0
# for i in range(len(df)):
#     if (df.at[i, 'Median Employee Pay'] == -1):
#         int += 1
#         print(i)
#         print(df.at[i, 'Company Name'])
# int

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %%
df

# %%
#verifying correctness

int = 0

for i in range(len(companies)):
    if (df_ratio.at[i, 'GICS Sector'] != companies1.at[i, 'GICS\xa0Sector'] or df_ratio.at[i, 'GICS Sub-Industry'] != companies1.at[i, 'GICS Sub-Industry']):
        int += 1
        print(df.at[i, 'Company Name'] + " is not " + companies1.at[i, 'Security'])
        print(i)
int

# %%
#df.to_csv('quick_names.csv',index=False)

# %%
#df_ratio.to_csv('official_ratio_with_industries.csv',index=False)
