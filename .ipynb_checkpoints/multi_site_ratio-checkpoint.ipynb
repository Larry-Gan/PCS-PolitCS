# %%
import requests
from requests.exceptions import ConnectionError
import lxml.html as lh
import pandas as pd
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
companies = pd.read_csv('List_of_companies.csv', encoding = "ISO-8859-1")

print(companies.dtypes)

companies['Security'] = companies['Security'].str.replace(r' ', '-')
companies['Security'] = companies['Security'].str.replace(r'.', '-')
companies['Security'] = companies['Security'].str.replace(r',', '-')
companies
# Out:
# Symbol                   object
# Security                 object
# SEC filings              object
# GICS Sector              object
# GICS Sub-Industry        object
# Headquarters Location    object
# Date first added         object
# CIK                       int64
# Founded                  object
# dtype: object
#     Symbol                                  Security SEC filings  \
# 0      MMM                                3M-Company     reports
# 1      ABT                       Abbott-Laboratories     reports
# 2     ABBV                               AbbVie-Inc-     reports
# 3     ABMD                               ABIOMED-Inc     reports
# 4      ACN                             Accenture-plc     reports
# 5     ATVI                       Activision-Blizzard     reports
# 6     ADBE                                Adobe-Inc-     reports
# 7      AMD                Advanced-Micro-Devices-Inc     reports
# 8      AAP                        Advance-Auto-Parts     reports
# 9      AES                                  AES-Corp     reports
# 10     AFL                                 AFLAC-Inc     reports
# 11       A                  Agilent-Technologies-Inc     reports
# 12     APD              Air-Products-&-Chemicals-Inc     reports
# 13    AKAM                   Akamai-Technologies-Inc     reports
# 14     ALK                      Alaska-Air-Group-Inc     reports
# 15     ALB                            Albemarle-Corp     reports
# 16     ARE           Alexandria-Real-Estate-Equities     reports
# 17    ALXN                   Alexion-Pharmaceuticals     reports
# 18    ALGN                          Align-Technology     reports
# 19    ALLE                                  Allegion     reports
# 20     LNT                       Alliant-Energy-Corp     reports
# 21     ALL                             Allstate-Corp     reports
# 22   GOOGL                   Alphabet-Inc- (Class-A)     reports
# 23    GOOG                   Alphabet-Inc- (Class-C)     reports
# 24      MO                          Altria-Group-Inc     reports
# 25    AMZN                           Amazon-com-Inc-     reports
# 26    AMCR                                 Amcor-plc     reports
# 27     AEE                               Ameren-Corp     reports
# 28     AAL                   American-Airlines-Group     reports
# 29     AEP                   American-Electric-Power     reports
# ..     ...                                       ...         ...
# 475    VNO                      Vornado-Realty-Trust     reports
# 476    VMC                          Vulcan-Materials     reports
# 477    WRB                 W--R--Berkley-Corporation     reports
# 478    WAB  Westinghouse-Air-Brake-Technologies-Corp     reports
# 479    WMT                                   Walmart     reports
# 480    WBA                  Walgreens-Boots-Alliance     reports
# 481    DIS                   The-Walt-Disney-Company     reports
# 482     WM                     Waste-Management-Inc-     reports
# 483    WAT                        Waters-Corporation     reports
# 484    WEC                          WEC-Energy-Group     reports
# 485    WFC                               Wells-Fargo     reports
# 486   WELL                            Welltower-Inc-     reports
# 487    WST              West-Pharmaceutical-Services     reports
# 488    WDC                           Western-Digital     reports
# 489     WU                          Western-Union-Co     reports
# 490    WRK                                  WestRock     reports
# 491     WY                              Weyerhaeuser     reports
# 492    WHR                           Whirlpool-Corp-     reports
# 493    WMB                        Williams-Companies     reports
# 494   WLTW                      Willis-Towers-Watson     reports
# 495   WYNN                          Wynn-Resorts-Ltd     reports
# 496    XEL                           Xcel-Energy-Inc     reports
# 497    XRX                                     Xerox     reports
# 498   XLNX                                    Xilinx     reports
# 499    XYL                                Xylem-Inc-     reports
# 8             Raleigh, North Carolina         7/9/2015  1158449         1932
# 9                 Arlington, Virginia        10/2/1998   874761         1981
# 10                  Columbus, Georgia        5/28/1999     4977         1955
# 11            Santa Clara, California         6/5/2000  1090872         1999
# 12            Allentown, Pennsylvania        4/30/1985     2969         1940
# 13           Cambridge, Massachusetts        7/12/2007  1086222         1998
# 14                Seattle, Washington        5/13/2016   766421         1985
# 15          Charlotte, North Carolina         7/1/2016   915913         1994
# 16               Pasadena, California        3/20/2017  1035443         1994
# 17              Boston, Massachusetts        5/25/2012   899866         1992
# 18               San Jose, California        6/19/2017  1097149         1997
# 19                    Dublin, Ireland        12/2/2013  1579241         1908
# 20                 Madison, Wisconsin         7/1/2016   352541         1917
# 21      Northfield Township, Illinois        7/13/1995   899051         1931
# 22          Mountain View, California         4/3/2014  1652044         1998
# 23          Mountain View, California         4/3/2006  1652044         1998
# 24                 Richmond, Virginia         3/4/1957   764180         1985
# 25                Seattle, Washington       11/18/2005  1018724         1994
# 26   Warmley, Bristol, United Kingdom         6/7/2019  1748790  2019 (1860)
# 27                St. Louis, Missouri        9/19/1991  1002910         1902
# 28                  Fort Worth, Texas        3/23/2015     6201         1934
# 29                     Columbus, Ohio         3/4/1957     4904         1906
# ..                                ...              ...      ...          ...
# 475                New York, New York              NaN   899689         1982
# 476               Birmingham, Alabama        6/30/1999  1396009         1909
# 477            Greenwich, Connecticut        12/5/2019    11544         1967
# 478          Wilmerding, Pennsylvania        2/27/2019   943452  1999 (1869)
# 479             Bentonville, Arkansas        8/31/1982   104169         1962
# 480               Deerfield, Illinois       12/31/1979  1618921         2014
# 481               Burbank, California        6/30/1976  1744489         1923
# 482                    Houston, Texas              NaN   823768         1968
# 483            Milford, Massachusetts              NaN  1000697         1958
# 484              Milwaukee, Wisconsin       10/31/2008   783325         1896
# 485         San Francisco, California        6/30/1976    72971         1852
# 486                      Toledo, Ohio        1/30/2009   766704         1970
# 487               Exton, Pennsylvania        5/22/2020   105770         1923
# 488              San Jose, California         7/1/2009   106040         1970
# 489               Englewood, Colorado        9/29/2006  1365135         1851
# 490                  Atlanta, Georgia              NaN  1732845         2015
# 491           Federal Way, Washington              NaN   106535         1900
# 492           Benton Harbor, Michigan              NaN   106640         1911
# 493                   Tulsa, Oklahoma        3/31/1975   107263         1908
# 494            London, United Kingdom         1/5/2016  1140536         2016
# 495                  Paradise, Nevada       11/14/2008  1174922         2002
# 496            Minneapolis, Minnesota         3/4/1957    72903         1909
# 497              Norwalk, Connecticut              NaN  1770450         1906
# 498              San Jose, California        11/8/1999   743988         1984
# 499            White Plains, New York        11/1/2011  1524472         2011
# 500              Louisville, Kentucky        10/6/1997  1041061         1997
# 501            Lincolnshire, Illinois       12/23/2019   877212         1969
# 502                   Warsaw, Indiana         8/7/2001  1136869         1927
# 503              Salt Lake City, Utah        6/22/2001   109380         1873
# 504          Florham Park, New Jersey        6/21/2013  1555280         1952
#
# [505 rows x 9 columns]

# %%
#getting url
url='https://www.salary.com/tools/executive-compensation-calculator/walmart-inc-executive-salaries?year=2020'
page=requests.get(url)

#getting all the tables
doc=lh.fromstring(page.content)
tr_elements=doc.xpath('//tr')

# %%
#making the csv to write into
filename = "ratio.csv"
f = open(filename, "w")

#writing in the header of the csv
headers = "CEO_Name, CEO_Pay, Median_Employee_Pay, CEO_Pay_Ratio\n"
f.write(headers)
# Out:
# 54

# %%
#seeing length of each row in the website
[len(T) for T in tr_elements[:]]
#I can probably use this to skip sites that don't have 4 columns
# Out:
# [4, 4, 2, 1, 2, 1, 1, 1, 2, 1, 2, 1, 1, 1, 2, 1, 2, 1, 1, 1, 2, 1, 2, 1, 1, 1]

# %%
tcol=[]
i=0

#seeing the content of a specified row this is for testing purposes only
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print(i,name)
    tcol.append((name, []))
tcol
# Out:
# 1 CEO Name
# 2 CEO Pay
# 3 Median Employee Pay
# 4 CEO Pay Ratio
# [('CEO Name', []),
#  ('CEO Pay', []),
#  ('Median Employee Pay', []),
#  ('CEO Pay Ratio', [])]

# %%
#write this into the csv
write_This = ""

#Makes a list of to make the graph later on
col=[('CEO Name', []), ('CEO Pay', []), ('Median Employee Pay', []), ('CEO Pay Ratio', [])]
col
# Out:
# [('CEO Name', []),
#  ('CEO Pay', []),
#  ('Median Employee Pay', []),
#  ('CEO Pay Ratio', [])]

# %%
#this will find the table that has the relevant info for the CEO,
#and put the correct info into col
for j in range(0,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]

    #Only check rows of size 4 (with CEO Name, CEO Pay, Median Employee Pay,
    #and CEO Pay Ratio)
    if len(T)==4:
        #checks if the current row has the 4 maagic words
        table_Name = ['','','','']
        i=0
        for t in T:
            name = t.text_content()
            name = name.__str__()
            table_Name[i]=name
            i+=1
        
        #if it does, I'll take the data from the row right below it
        if (table_Name[0] == 'CEO Name' and table_Name[1] == 'CEO Pay' and table_Name[2] == 'Median Employee Pay' and table_Name[3] == 'CEO Pay Ratio'):
            T=tr_elements[j+1]
            #i is the index of our column
            i=0
            
            #this is a temporary storage of the content of each line of the csv
            content = []
            
            #Iterate through each element of the row
            for t in T.iterchildren():
                #this part if for cleaning the cell contents
                data=t.text_content() #gets the content of cell
                data = data.__str__() #turns content to string
                data = data.replace(r'$', '') #takes out dollar sign for number conversion
                data = data.replace(r',', '') #takes out comma for number conversion
                data = data.strip() #clears our \r and \n and spaces, cleans up the content string
                data = data.replace(r'CEO Pay', '') #cleans up the content string
                data = data.replace(r'Median Employee Pay', '') #cleans up the content string
                data = data.replace(r'CEO Pay Ratio', '') #cleans up the content string
                data = data.replace(r'Ratio', '') #cleans up the content string
                data = data.replace(r':1', '') #takes out :1 in the ratio for number conversion
                data = data.strip() #clears our \r and \n and spaces again to finish cleaning up
                
                content.append(data)
                
                #Check if row is empty
                if i>0:
                #Convert any numerical value to integers
                    try:
                        data=int(data)
                    except:
                        pass
                #Append the data to col
                col[i][1].append(data)
                #Increment i for the next column
                i+=1
            write_This = content[0]
            for j in range(1, len(content)):
                write_This += ", " + content[j]
            write_This += "\n"
            f.write(write_This)
            break

# %%
write_This
# Out:
# 'C. Douglas McMillon, 22105350, 22484, 983\n'

# %%
f.close()

# %%
#making the dataframe
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %%
#displaying the dataframe
df
# Out:
#               CEO Name   CEO Pay  Median Employee Pay  CEO Pay Ratio
# 0  C. Douglas McMillon  22105350                22484            983
